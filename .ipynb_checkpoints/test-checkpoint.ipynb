# %% [markdown]
# # Experimentation Env for my project

# %%
import numpy as np


def generate_snapshot(mid_price):
    rand = np.random.default_rng()
    c_speed = np.random
    price = 
    quantity = 
    # returns array of shape (6, 3)
    # 3 buy levels, 3 sell levels
    # each row: [price, quantity, cancellation_speed]
